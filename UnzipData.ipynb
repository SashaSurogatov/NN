# %%
import zipfile

root = '../../Data/'
for i in xrange(21, 71):
    for j in ['m', 'f']:
        dirName = root + str(i) + '_' + j
        zip_ref = zipfile.ZipFile(dirName + '.zip', 'r')
        print zip_ref
        print zip_ref.extractall(root)
        zip_ref.close()
# Out:
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None
# ...
# None

# %%
import os, shutil
folder = '../../Data/'
for the_file in os.listdir(folder):
    file_path = os.path.join(folder, the_file)
    try:
        if os.path.isfile(file_path):
            #os.unlink(file_path)
            print (file_path)
        elif the_file != 'Sick' and os.path.isdir(file_path): shutil.rmtree(file_path)
    except Exception as e:
        print(e)
# Out:
# ../../Data/31_f.zip
# ../../Data/34_m.zip
# ../../Data/46_f.zip
# ../../Data/60_f.zip
# ../../Data/45_m.zip
# ../../Data/49_m.zip
# ../../Data/32_m.zip
# ../../Data/67_f.zip
# ../../Data/54_f.zip
# ../../Data/48_f.zip
# ../../Data/65_f.zip
# ../../Data/50_m.zip
# ../../Data/21_m.zip
# ../../Data/70_f.zip
# ../../Data/55_m.zip
# ../../Data/53_m.zip
# ../../Data/68_f.zip
# ../../Data/62_m.zip
# ../../Data/61_m.zip
# ../../Data/66_f.zip
# ../../Data/27_f.zip
# ../../Data/62_f.zip
# ../../Data/24_m.zip
# ../../Data/60_m.zip
# ../../Data/29_m.zip
# ../../Data/33_m.zip
# ../../Data/54_m.zip
# ../../Data/25_f.zip
# ../../Data/55_f.zip
# ../../Data/67_m.zip
# ../../Data/21_f.zip
# ../../Data/56_f.zip
# ../../Data/28_m.zip
# ../../Data/46_m.zip
# ../../Data/42_f.zip
# ../../Data/63_f.zip
# ../../Data/65_m.zip
# ../../Data/26_m.zip
# ../../Data/37_m.zip
# ../../Data/51_f.zip
# ../../Data/35_f.zip
# ../../Data/68_m.zip
# ../../Data/45_f.zip
# ../../Data/38_m.zip
# ../../Data/53_f.zip
# ...
